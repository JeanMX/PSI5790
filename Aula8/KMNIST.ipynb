# %% [markdown]
# # Exercício 1 - Aula 8 - PSI5790
#
# ### Nome: Jean Carlos Mello Xavier Faria
# ### Nusp: 11259628

# %%
import os; os.environ['TF_CPP_MIN_LOG_LEVEL']='3'
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
import tensorflow.keras as keras
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Normalization, Dropout,RandomFlip, RandomZoom, RandomRotation
from tensorflow.keras import optimizers
import numpy as np; import sys

from tensorflow.keras.layers import Dropout, Conv2D, MaxPooling2D, Dense, Flatten
from time import time

# %%
import requests

try:
    from tqdm import tqdm
except ImportError:
    tqdm = lambda x, total, unit: x  # If tqdm doesn't exist, replace it with a function that does nothing
    print('**** Could not import tqdm. Please install tqdm for download progressbars! (pip install tqdm) ****')

# Python2 compatibility
try:
    input = raw_input
except NameError:
    pass

download_dict = {
    '1) Kuzushiji-MNIST (10 classes, 28x28, 70k examples)': {
        '1) MNIST data format (ubyte.gz)':
            ['http://codh.rois.ac.jp/kmnist/dataset/kmnist/train-images-idx3-ubyte.gz',
            'http://codh.rois.ac.jp/kmnist/dataset/kmnist/train-labels-idx1-ubyte.gz',
            'http://codh.rois.ac.jp/kmnist/dataset/kmnist/t10k-images-idx3-ubyte.gz',
            'http://codh.rois.ac.jp/kmnist/dataset/kmnist/t10k-labels-idx1-ubyte.gz'],
        '2) NumPy data format (.npz)':
            ['http://codh.rois.ac.jp/kmnist/dataset/kmnist/kmnist-train-imgs.npz',
            'http://codh.rois.ac.jp/kmnist/dataset/kmnist/kmnist-train-labels.npz',
            'http://codh.rois.ac.jp/kmnist/dataset/kmnist/kmnist-test-imgs.npz',
            'http://codh.rois.ac.jp/kmnist/dataset/kmnist/kmnist-test-labels.npz'],
    },
    '2) Kuzushiji-49 (49 classes, 28x28, 270k examples)': {
        '1) NumPy data format (.npz)':
            ['http://codh.rois.ac.jp/kmnist/dataset/k49/k49-train-imgs.npz',
            'http://codh.rois.ac.jp/kmnist/dataset/k49/k49-train-labels.npz',
            'http://codh.rois.ac.jp/kmnist/dataset/k49/k49-test-imgs.npz',
            'http://codh.rois.ac.jp/kmnist/dataset/k49/k49-test-labels.npz'],
    },
    '3) Kuzushiji-Kanji (3832 classes, 64x64, 140k examples)': {
        '1) Folders of images (.tar)':
            ['http://codh.rois.ac.jp/kmnist/dataset/kkanji/kkanji.tar'],
    }

}

# Download a list of files
def download_list(url_list):
    for url in url_list:
        path = url.split('/')[-1]
        r = requests.get(url, stream=True)
        with open(path, 'wb') as f:
            total_length = int(r.headers.get('content-length'))
            print('Downloading {} - {:.1f} MB'.format(path, (total_length / 1024000)))

            for chunk in tqdm(r.iter_content(chunk_size=1024), total=int(total_length / 1024) + 1, unit="KB"):
                if chunk:
                    f.write(chunk)
    print('All dataset files downloaded!')

# Ask the user about which path to take down the dict
def traverse_dict(d):
    print('Please select a download option:')
    keys = sorted(d.keys())  # Print download options
    for key in keys:
        print(key)

    userinput = input('> ').strip()

    try:
        selection = int(userinput) - 1
    except ValueError:
        print('Your selection was not valid')
        traverse_dict(d)  # Try again if input was not valid
        return

    selected = keys[selection]

    next_level = d[selected]
    if isinstance(next_level, list):  # If we've hit a list of downloads, download that list
        download_list(next_level)
    else:
        traverse_dict(next_level)     # Otherwise, repeat with the next level

traverse_dict(download_dict)
# Out:
# Please select a download option:
# 1) Kuzushiji-MNIST (10 classes, 28x28, 70k examples)
# 2) Kuzushiji-49 (49 classes, 28x28, 270k examples)
# 3) Kuzushiji-Kanji (3832 classes, 64x64, 140k examples)
# > 1
# Please select a download option:
# 1) MNIST data format (ubyte.gz)
# 2) NumPy data format (.npz)
# > 2
# Downloading kmnist-train-imgs.npz - 18.0 MB
# 100%|██████████| 17954/17954 [00:09<00:00, 1962.01KB/s]
# Downloading kmnist-train-labels.npz - 0.0 MB
# 100%|██████████| 30/30 [00:00<00:00, 397.18KB/s]
# Downloading kmnist-test-imgs.npz - 3.0 MB
# 100%|██████████| 3008/3008 [00:01<00:00, 1796.60KB/s]
# Downloading kmnist-test-labels.npz - 0.0 MB
# 100%|██████████| 6/6 [00:00<00:00, 6388.89KB/s]
# All dataset files downloaded!

# %%
AX = np.load("kmnist-train-imgs.npz")['arr_0']
AY = np.load("kmnist-train-labels.npz")['arr_0']
QX = np.load("kmnist-test-imgs.npz")['arr_0']
QY = np.load("kmnist-test-labels.npz")['arr_0']
AX=255-AX; QX=255-QX
nl, nc = AX.shape[1], AX.shape[2] #28, 28
AX = (AX.astype('float32')/255.0)-0.5 # -0.5 a +0.5
QX = (QX.astype('float32')/255.0)-0.5 # -0.5 a +0.5
nclasses = 10

# %%
model = Sequential()
model.add(Normalization(input_shape=(nl,nc))) #Normaliza
model.add(Flatten())
model.add(Dense(1000, activation='sigmoid'))
model.add(Dropout(0.3))
model.add(Dense(400, activation='sigmoid'))
model.add(Dropout(0.3))
model.add(Dense(400, activation='sigmoid'))
model.add(Dropout(0.3))
model.add(Dense(nclasses, activation='sigmoid'))
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='mlp1.png', show_shapes=True)
model.summary()
opt=optimizers.Adam(learning_rate=0.0005)
model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.get_layer(index=0).adapt(AX) #Calcula media e desvio
model.fit(AX, AY, batch_size=100, epochs=40, verbose=2)
score = model.evaluate(QX, QY, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
model.save('mlp1.keras')
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization_1 (Normaliza  (None, 28, 28)            57
#  tion)
#
#  flatten_2 (Flatten)         (None, 784)               0
#
#  dense_6 (Dense)             (None, 1000)              785000
#
#  dropout_6 (Dropout)         (None, 1000)              0
#
#  dense_7 (Dense)             (None, 400)               400400
#
#  dropout_7 (Dropout)         (None, 400)               0
#
#  dense_8 (Dense)             (None, 400)               160400
#
#  dropout_8 (Dropout)         (None, 400)               0
#
#  dense_9 (Dense)             (None, 10)                4010
#
# =================================================================
# Total params: 1349867 (5.15 MB)
# Trainable params: 1349810 (5.15 MB)
# Non-trainable params: 57 (232.00 Byte)
# _________________________________________________________________
# Epoch 1/40
# 600/600 - 5s - loss: 0.7964 - accuracy: 0.7514 - 5s/epoch - 8ms/step
# Epoch 2/40
# 600/600 - 2s - loss: 0.3831 - accuracy: 0.8837 - 2s/epoch - 3ms/step
# Epoch 3/40
# 600/600 - 2s - loss: 0.2744 - accuracy: 0.9160 - 2s/epoch - 3ms/step
# Epoch 4/40
# 600/600 - 2s - loss: 0.2120 - accuracy: 0.9363 - 2s/epoch - 3ms/step
# Epoch 5/40
# 600/600 - 2s - loss: 0.1693 - accuracy: 0.9490 - 2s/epoch - 3ms/step
# Epoch 6/40
# 600/600 - 2s - loss: 0.1407 - accuracy: 0.9563 - 2s/epoch - 3ms/step
# Epoch 7/40
# 600/600 - 2s - loss: 0.1196 - accuracy: 0.9627 - 2s/epoch - 3ms/step
# Epoch 8/40
# 600/600 - 2s - loss: 0.1009 - accuracy: 0.9690 - 2s/epoch - 4ms/step
# Epoch 9/40
# 600/600 - 2s - loss: 0.0876 - accuracy: 0.9727 - 2s/epoch - 3ms/step
# Epoch 10/40
# 600/600 - 2s - loss: 0.0770 - accuracy: 0.9761 - 2s/epoch - 3ms/step
# Epoch 11/40
# 600/600 - 2s - loss: 0.0658 - accuracy: 0.9785 - 2s/epoch - 3ms/step
# Epoch 12/40
# 600/600 - 2s - loss: 0.0612 - accuracy: 0.9803 - 2s/epoch - 3ms/step
# Epoch 13/40
# 600/600 - 2s - loss: 0.0545 - accuracy: 0.9824 - 2s/epoch - 3ms/step
# Epoch 14/40
# 600/600 - 2s - loss: 0.0486 - accuracy: 0.9843 - 2s/epoch - 3ms/step
# Epoch 15/40
# 600/600 - 2s - loss: 0.0430 - accuracy: 0.9861 - 2s/epoch - 3ms/step
# Epoch 16/40
# 600/600 - 2s - loss: 0.0402 - accuracy: 0.9866 - 2s/epoch - 3ms/step
# Epoch 17/40
# 600/600 - 2s - loss: 0.0386 - accuracy: 0.9873 - 2s/epoch - 3ms/step
# Epoch 18/40
# 600/600 - 2s - loss: 0.0349 - accuracy: 0.9881 - 2s/epoch - 3ms/step
# Epoch 19/40
# 600/600 - 2s - loss: 0.0322 - accuracy: 0.9891 - 2s/epoch - 3ms/step
# Epoch 20/40
# 600/600 - 2s - loss: 0.0304 - accuracy: 0.9901 - 2s/epoch - 3ms/step
# Epoch 21/40
# 600/600 - 2s - loss: 0.0287 - accuracy: 0.9905 - 2s/epoch - 3ms/step
# Epoch 22/40
# 600/600 - 2s - loss: 0.0263 - accuracy: 0.9912 - 2s/epoch - 3ms/step
# Epoch 23/40
# 600/600 - 2s - loss: 0.0250 - accuracy: 0.9914 - 2s/epoch - 3ms/step
# Epoch 24/40
# 600/600 - 2s - loss: 0.0251 - accuracy: 0.9915 - 2s/epoch - 3ms/step
# Epoch 25/40
# 600/600 - 2s - loss: 0.0228 - accuracy: 0.9919 - 2s/epoch - 3ms/step
# Epoch 26/40
# 600/600 - 2s - loss: 0.0212 - accuracy: 0.9928 - 2s/epoch - 4ms/step
# Epoch 27/40
# 600/600 - 2s - loss: 0.0204 - accuracy: 0.9933 - 2s/epoch - 3ms/step
# Epoch 28/40
# 600/600 - 2s - loss: 0.0202 - accuracy: 0.9930 - 2s/epoch - 3ms/step
# Epoch 29/40
# 600/600 - 2s - loss: 0.0186 - accuracy: 0.9939 - 2s/epoch - 3ms/step
# Epoch 30/40
# 600/600 - 2s - loss: 0.0178 - accuracy: 0.9936 - 2s/epoch - 3ms/step
# Epoch 31/40
# 600/600 - 2s - loss: 0.0191 - accuracy: 0.9933 - 2s/epoch - 3ms/step
# Epoch 32/40
# 600/600 - 2s - loss: 0.0172 - accuracy: 0.9945 - 2s/epoch - 3ms/step
# Epoch 33/40
# 600/600 - 2s - loss: 0.0167 - accuracy: 0.9944 - 2s/epoch - 3ms/step
# Epoch 34/40
# 600/600 - 2s - loss: 0.0154 - accuracy: 0.9949 - 2s/epoch - 3ms/step
# Epoch 35/40
# 600/600 - 2s - loss: 0.0155 - accuracy: 0.9948 - 2s/epoch - 3ms/step
# Epoch 36/40
# 600/600 - 2s - loss: 0.0152 - accuracy: 0.9949 - 2s/epoch - 3ms/step
# Epoch 37/40
# 600/600 - 2s - loss: 0.0160 - accuracy: 0.9946 - 2s/epoch - 4ms/step
# Epoch 38/40
# 600/600 - 2s - loss: 0.0144 - accuracy: 0.9953 - 2s/epoch - 3ms/step
# Epoch 39/40
# 600/600 - 2s - loss: 0.0144 - accuracy: 0.9951 - 2s/epoch - 3ms/step
# Epoch 40/40
# 600/600 - 2s - loss: 0.0148 - accuracy: 0.9948 - 2s/epoch - 3ms/step
# Test loss: 0.44022640585899353
# Test accuracy: 0.919700026512146

# %%
model = Sequential() # 28x28
model.add(Conv2D(40, kernel_size=(5,5), activation='relu', input_shape=(nl, nc, 1) )) #40x24x24
model.add(Dropout(0.3))
model.add(MaxPooling2D(pool_size=(2,2))) #40x12x12
model.add(Conv2D(80, kernel_size=(5,5), activation='relu')) #80x8x8
model.add(Dropout(0.3))
model.add(MaxPooling2D(pool_size=(2,2))) #80x4x4
model.add(Flatten()) #1280
model.add(Dense(400, activation='relu')) #400
model.add(Dropout(0.3))
model.add(Dense(nclasses, activation='softmax')) #10
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='cnn1.png', show_shapes=True)
model.summary()
opt=optimizers.Adam()
model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
t0=time()
model.fit(AX, AY, batch_size=100, epochs=30, verbose=2)
t1=time(); print("Tempo de treino: %.2f s"%(t1-t0))
score = model.evaluate(QX, QY, verbose=False)
print('Test loss: %.4f'%(score[0]))
print('Test accuracy: %.2f %%'%(100*score[1]))
print('Test error: %.2f %%'%(100*(1-score[1])))
t2=time()
QP2=model.predict(QX); QP=np.argmax(QP2,1)
t3=time(); print("Tempo de predicao: %.2f s"%(t3-t2))
nerro=np.count_nonzero(QP-QY); print("nerro=%d"%(nerro))
model.save('cnn1.keras')
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 24, 24, 40)        1040
#
#  dropout_9 (Dropout)         (None, 24, 24, 40)        0
#
#  max_pooling2d_2 (MaxPoolin  (None, 12, 12, 40)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 80)          80080
#
#  dropout_10 (Dropout)        (None, 8, 8, 80)          0
#
#  max_pooling2d_3 (MaxPoolin  (None, 4, 4, 80)          0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 1280)              0
#
#  dense_10 (Dense)            (None, 400)               512400
#
#  dropout_11 (Dropout)        (None, 400)               0
#
#  dense_11 (Dense)            (None, 10)                4010
#
# =================================================================
# Total params: 597530 (2.28 MB)
# Trainable params: 597530 (2.28 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/30
# 600/600 - 3s - loss: 0.3089 - accuracy: 0.9037 - 3s/epoch - 6ms/step
# Epoch 2/30
# 600/600 - 2s - loss: 0.0921 - accuracy: 0.9722 - 2s/epoch - 4ms/step
# Epoch 3/30
# 600/600 - 2s - loss: 0.0621 - accuracy: 0.9811 - 2s/epoch - 4ms/step
# Epoch 4/30
# 600/600 - 2s - loss: 0.0469 - accuracy: 0.9854 - 2s/epoch - 4ms/step
# Epoch 5/30
# 600/600 - 2s - loss: 0.0390 - accuracy: 0.9878 - 2s/epoch - 4ms/step
# Epoch 6/30
# 600/600 - 2s - loss: 0.0294 - accuracy: 0.9908 - 2s/epoch - 4ms/step
# Epoch 7/30
# 600/600 - 2s - loss: 0.0274 - accuracy: 0.9913 - 2s/epoch - 4ms/step
# Epoch 8/30
# 600/600 - 2s - loss: 0.0242 - accuracy: 0.9921 - 2s/epoch - 4ms/step
# Epoch 9/30
# 600/600 - 2s - loss: 0.0209 - accuracy: 0.9930 - 2s/epoch - 4ms/step
# Epoch 10/30
# 600/600 - 2s - loss: 0.0210 - accuracy: 0.9932 - 2s/epoch - 4ms/step
# Epoch 11/30
# 600/600 - 2s - loss: 0.0161 - accuracy: 0.9947 - 2s/epoch - 4ms/step
# Epoch 12/30
# 600/600 - 2s - loss: 0.0172 - accuracy: 0.9944 - 2s/epoch - 4ms/step
# Epoch 13/30
# 600/600 - 2s - loss: 0.0176 - accuracy: 0.9942 - 2s/epoch - 4ms/step
# Epoch 14/30
# 600/600 - 2s - loss: 0.0140 - accuracy: 0.9957 - 2s/epoch - 4ms/step
# Epoch 15/30
# 600/600 - 2s - loss: 0.0126 - accuracy: 0.9957 - 2s/epoch - 4ms/step
# Epoch 16/30
# 600/600 - 2s - loss: 0.0141 - accuracy: 0.9952 - 2s/epoch - 4ms/step
# Epoch 17/30
# 600/600 - 2s - loss: 0.0145 - accuracy: 0.9956 - 2s/epoch - 4ms/step
# Epoch 18/30
# 600/600 - 2s - loss: 0.0108 - accuracy: 0.9966 - 2s/epoch - 4ms/step
# Epoch 19/30
# 600/600 - 2s - loss: 0.0107 - accuracy: 0.9968 - 2s/epoch - 4ms/step
# Epoch 20/30
# 600/600 - 2s - loss: 0.0125 - accuracy: 0.9961 - 2s/epoch - 4ms/step
# Epoch 21/30
# 600/600 - 2s - loss: 0.0107 - accuracy: 0.9965 - 2s/epoch - 4ms/step
# Epoch 22/30
# 600/600 - 2s - loss: 0.0115 - accuracy: 0.9966 - 2s/epoch - 4ms/step
# Epoch 23/30
# 600/600 - 2s - loss: 0.0106 - accuracy: 0.9965 - 2s/epoch - 4ms/step
# Epoch 24/30
# 600/600 - 2s - loss: 0.0086 - accuracy: 0.9973 - 2s/epoch - 4ms/step
# Epoch 25/30
# 600/600 - 2s - loss: 0.0092 - accuracy: 0.9972 - 2s/epoch - 4ms/step
# Epoch 26/30
# 600/600 - 2s - loss: 0.0088 - accuracy: 0.9970 - 2s/epoch - 4ms/step
# Epoch 27/30
# 600/600 - 2s - loss: 0.0102 - accuracy: 0.9969 - 2s/epoch - 4ms/step
# Epoch 28/30
# 600/600 - 2s - loss: 0.0101 - accuracy: 0.9969 - 2s/epoch - 4ms/step
# Epoch 29/30
# 600/600 - 2s - loss: 0.0077 - accuracy: 0.9977 - 2s/epoch - 4ms/step
# Epoch 30/30
# 600/600 - 2s - loss: 0.0091 - accuracy: 0.9974 - 2s/epoch - 4ms/step
# Tempo de treino: 83.03 s
# Test loss: 0.1639
# Test accuracy: 96.67 %
# Test error: 3.33 %
# 313/313 [==============================] - 1s 2ms/step
# Tempo de predicao: 1.39 s
# nerro=333
